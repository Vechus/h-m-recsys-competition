# %%
import glob
import json
import os
import re

import pandas as pd
from dotenv import load_dotenv

dataframe = pd.DataFrame()

load_dotenv()
RESULT_PATH = os.getenv('RESULT_PATH')

for filename in list(glob.glob(RESULT_PATH+'/ItemKNNCBF_CFCBF/*.txt')):
    with open(filename) as fh:
        for line in fh:
            if 'New best config found' in line:
                best_line = line

        configure = re.search('{(.*)}', best_line).group(1)
        config = ''
        for i in configure.split(', '):
            i1 = i.split(':')[0].replace('\'','')
            i1 += '='
            i2 = i.split(':')[1].replace(' ','')
            i = i1+i2
            i+=','
            config += i
        config = config[:-1]
        MAP = re.search('MAP: (\d+.\d+)',best_line).group(1)
        df_new={'Best config': config, 'MAP': MAP}
        df_new = pd.DataFrame(data=df_new, index= [filename.split('/')[-1].replace('.txt', '')])

    dataframe = dataframe.append(df_new)
print(dataframe)
dataframe.sort_values(by=['MAP'],inplace=True,ascending=False)
dataframe.to_excel(RESULT_PATH+'/ItemKNNCBF_CFCBF/'+'output.xlsx')
# Out:
#                                                                                           Best config  \
# ItemKNNCBFRecommender_ICM_on_discount_asymmetri...  topK=327,shrink=312,similarity='asymmetric',no...
# ItemKNNCBFRecommender_ICM_section_no_tversky_Se...  topK=724,shrink=649,similarity='tversky',norma...
# ItemKNN_CFCBF_HybridRecommender_ICM_cleaned_pro...  topK=518,shrink=1000,similarity='asymmetric',n...
# ItemKNNCBFRecommender_ICM_cleaned_product_type_...  topK=996,shrink=161,similarity='tversky',norma...
# ItemKNN_CFCBF_HybridRecommender_ICM_perceived_c...  topK=902,shrink=179,similarity='cosine',normal...
# ...                                                                                               ...
# ItemKNN_CFCBF_HybridRecommender_ICM_colour_grou...  topK=989,shrink=894,similarity='jaccard',norma...
# ItemKNN_CFCBF_HybridRecommender_ICM_cleaned_col...  topK=968,shrink=553,similarity='cosine',normal...
# ...

# %%
a = json.dumps("'PRECISION': 0.0012195, 'PRECISION_RECALL_MIN_DEN': 0.0049465")

# %%
print(a)
# Out:
# "'PRECISION': 0.0012195, 'PRECISION_RECALL_MIN_DEN': 0.0049465"

# %%
df1 = pd.DataFrame([['a', 'b'], ['c', 'd']],
                   index=['row 1', 'row 2'],
                   columns=['col 1', 'col 2'])
df1.to_excel("output.xlsx")

# %%
x =  '{ "name":"John", "age":30, "city":"New York"}'


y = pd.read_csv
y.to_excel("output.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [48], in <cell line: 4>()
#       1 x =  '{ "name":"John", "age":30, "city":"New York"}'
# ----> 4 y = pd.read_csv(x)
#       5 y.to_excel("output.xlsx")
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 y.to_excel("output.xlsx")
#
# AttributeError: 'dict' object has no attribute 'to_excel'

# %%
import glob
import json
import os
import re

import pandas as pd
from dotenv import load_dotenv

columns = ['ICM name','Best config','MAP']
dataframe = pd.DataFrame(columns=columns)

load_dotenv()
RESULT_PATH = os.getenv('RESULT_PATH')
result_name = '/ItemKNNCBF_CFCBF'

for filename in list(glob.glob(RESULT_PATH + result_name + '/*.txt')):
    with open(filename) as fh:
        for line in fh:
            if 'New best config found' in line:
                best_line = line

        configure = re.search('{(.*)}', best_line).group(1)
        config = ''
        for i in configure.split(', '):
            i1 = i.split(':')[0].replace('\'', '')
            i1 += '='
            i2 = i.split(':')[1].replace(' ', '')
            i = i1 + i2
            i += ','
            config += i
        config = config[:-1]
        MAP = re.search('MAP: (\\d+.\\d+)', best_line).group(1)
        df_new = {'ICM name':re.search('ICM_.*_SearchBayesianSkopt', filename).group(0).rsplit('_', 2)[0],
              'Best config': config,
              'MAP': MAP}
        df_new = pd.DataFrame(data=df_new, index=[filename.split('/')[-1].replace('.txt', '')])
    print(dataframe['ICM name'].equals(df_new['ICM name']))

    dataframe = dataframe.append(df_new)

# print(dataframe)
# dataframe.sort_values(by=['MAP'], inplace=True, ascending=False)
# dataframe.to_excel(RESULT_PATH + result_name + '/output.xlsx')
# print("Completed!!!")
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...
